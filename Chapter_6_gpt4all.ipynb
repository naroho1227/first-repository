# %% [markdown]
# <a href="https://colab.research.google.com/github/naroho1227/first-repository/blob/main/Chapter_6_gpt4all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT4ALL 소개와 환경 설정
#
# **단국대학교 — LLM기반 서비스 개발의 이해**
#
# 이 노트북에서는 다음을 실습합니다:
# 1. GPT4ALL Python 라이브러리 설치
# 2. 모델 로드 및 기본 텍스트 생성
# 3. 하이퍼파라미터 실험 (Temperature, Top-P, Top-K)
# 4. GPU(CUDA) 가속 사용
#
# ---
# ## 0. 환경 준비
#
# GPT4ALL Python 라이브러리를 설치합니다. Colab 또는 로컬 환경 모두 동일합니다.

# %%
# !pip install gpt4all
# Out:
# Requirement already satisfied: gpt4all in /usr/local/lib/python3.12/dist-packages (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gpt4all) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gpt4all) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (2026.4.22)

# %%
# !pip install "gpt4all[cuda]"
# Out:
# Requirement already satisfied: gpt4all[cuda] in /usr/local/lib/python3.12/dist-packages (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gpt4all[cuda]) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gpt4all[cuda]) (4.67.3)
# Collecting nvidia-cuda-runtime-cu11 (from gpt4all[cuda])
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cublas-cu11 (from gpt4all[cuda])
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (2026.4.22)
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 43.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cublas-cu11
# Successfully installed nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-runtime-cu11-11.8.89

# %% [markdown]
# 모델 파일 저장 경로를 설정합니다. GPT4ALL GUI에서 다운로드한 모델이 있다면 해당 경로를 지정해도 됩니다.

# %%
import os
dirmodel = 'gpt4all_models'

# %% [markdown]
# ---
# ## 1. 모델 로드 & 기본 텍스트 생성
#
# GPT4All 객체를 생성하면서 모델 파일을 지정합니다.
# 처음 실행 시 모델 파일(약 4.66GB)이 자동으로 다운로드됩니다.
#
# ```
# GPT4All(모델명) → 모델 로드
# model.chat_session() → 채팅 세션 시작
# model.generate(프롬프트) → 텍스트 생성
# ```

# %%
from gpt4all import GPT4All
model = GPT4All("Meta-Llama-3-8B-Instruct.Q4_0.gguf") # downloads / loads a 4.66GB LLM
# Out:
# Downloading: 100%|██████████| 4.66G/4.66G [01:08<00:00, 67.9MiB/s]
# Verifying: 100%|██████████| 4.66G/4.66G [00:13<00:00, 351MiB/s]

# %%
with model.chat_session():
    print(model.generate("How can I run LLMs efficiently on my laptop?", max_tokens=1024))
# Out:
# Large Language Models (LLMs) are powerful AI models that require significant computational resources to train and use. Running them efficiently on your laptop requires a combination of hardware, software, and technique optimizations. Here's a comprehensive guide to help you get the most out of your LLMs:
#
# **Hardware Optimizations**
#
# 1. **Processor**: Look for laptops with at least 4-6 cores (e.g., Intel Core i7 or AMD Ryzen 7). More cores can significantly speed up computations.
# 2. **Memory**: Ensure your laptop has sufficient RAM (at least 16 GB, but 32 GB or more is recommended).
# 3. **Graphics Card**: A dedicated graphics card with at least 4-6 GB of VRAM can help accelerate computations.
#
# **Software Optimizations**
#
# 1. **LLM Frameworks**: Use frameworks like TensorFlow, PyTorch, or JAX that are optimized for LLM training and inference.
# 2. **GPU Support**: Install GPU drivers (e.g., NVIDIA CUDA or AMD ROCm) to utilize your laptop's graphics card for computations.
# 3. **Optimized Libraries**: Utilize libraries like OpenBLAS, MKL, or cuDNN that provide optimized implementations of linear algebra operations.
#
# **Technique Optimizations**
#
# 1. **Batching and Parallelization**: Split large datasets into smaller batches and use parallel processing techniques (e.g., data parallelism) to speed up computations.
# 2. **Model Pruning**: Remove unnecessary weights from the model to reduce computational requirements without sacrificing performance.
# 3. **Knowledge Distillation**: Train a smaller, more efficient model on top of a pre-trained LLM to transfer knowledge while reducing computation.
#
# **Additional Tips**
#
# 1. **Use Cloud Services**: Consider using cloud services like Google Colab, AWS SageMaker, or Azure Machine Learning that provide scalable infrastructure and optimized frameworks for LLM training.
# 2. **Optimize Your Code**: Use profiling tools (e.g., TensorFlow's `tf.profiler`) to identify performance bottlenecks in your code and optimize accordingly.
# 3. **Monitor Resource Utilization**: Keep an eye on CPU, memory, and GPU usage to ensure you're not overloading your laptop.
#
# **Example Laptop Specifications**
#
# To give you a rough idea of what kind of laptop specifications can support LLMs efficiently:
#
# * Processor: Intel Core i9 or AMD Ryzen 9
# * Memory: 32 GB RAM (or more)
# * Graphics Card: NVIDIA GeForce RTX 3070 or AMD Radeon RX 6800M
#
# Keep in mind that these are general guidelines, and the specific requirements will depend on the size of your LLMs, dataset sizes, and computational tasks.
#
# By following these tips and optimizing your laptop's hardware, software, and techniques, you'll be able to run LLMs efficiently and effectively. Happy computing!

# %% [markdown]
# 위 결과가 나오기까지 시간이 걸렸을 겁니다(CPU 기준 약 1~2분).
# 이것이 **On-device LLM**입니다 — 느리지만, 내 컴퓨터에서 돌아간다!
#
# 뒤에서 GPU를 사용하면 훨씬 빨라지는 것을 확인할 수 있습니다.

# %% [markdown]
# ---
# ## 2. 하이퍼파라미터 실험
#
# 슬라이드에서 배운 하이퍼파라미터들을 코드로 직접 실험해봅시다.
#
# | 파라미터 | 역할 | 값이 낮으면 | 값이 높으면 |
# |---------|------|-----------|------------|
# | Temperature | 응답 다양성 조절 | 항상 같은 응답 | 다양한 응답 |
# | Top P | 누적 확률 기준 토큰 선택 | 소수의 토큰만 고려 | 더 많은 토큰 고려 |
# | Top K | 상위 K개 토큰만 선택 | 선택지 적음 | 선택지 많음 |
#
# ### 2-1. Temperature 실험
#
# **temp=0.0**: 같은 질문에 항상 같은 답변이 나와야 합니다.
# 5번 반복 실행하면서 결과가 동일한지 확인해보세요.

# %%
for i in range(5):
    with model.chat_session():
        result = model.generate("Define love", max_tokens=200, temp=0.0)
        print(f"--- 시도 {i+1} ---")
        print(result)
        print()
# Out:
# --- 시도 1 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment
#
# --- 시도 2 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment
#
# --- 시도 3 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment
#
# --- 시도 4 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment
#
# --- 시도 5 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment

# %% [markdown]
# **temp=1.0**: 같은 질문이지만 매번 다른 답변이 나올 수 있습니다.
# 위 결과와 비교해보세요!

# %%
for i in range(5):
    with model.chat_session():
        result = model.generate("Define love", max_tokens=1000, temp=1.0)
        print(f"--- 시도 {i+1} ---")
        print(result)
        print()
# Out:
# --- 시도 1 ---
# The age-old question: what is love?
#
# Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. While it's difficult to define with absolute precision, here are some common aspects of love:
#
# 1. **Emotional connection**: Love often involves an intense emotional bond between two individuals or entities (e.g., romantic partners, family members, friends). This connection can be characterized by feelings such as warmth, tenderness, and a deep sense of understanding.
# 2. **Positive emotions**: Love is frequently accompanied by positive emotions like joy, happiness, contentment, and euphoria. These feelings can arise from the presence or thought of the loved one, leading to an overall sense of well-being.
# 3. **Unconditional acceptance**: True love often involves accepting someone for who they are, without judgment or expectation of change. This unconditional acceptance fosters a safe and supportive environment where individuals feel valued and appreciated.
# 4. **Commitment and loyalty**:
#
# --- 시도 2 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection with another person, place, or thing that involves strong feelings of affection, attachment, care, commitment, and devotion. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and unconditional love.
#
# Some key characteristics of love include:
#
# 1. **Emotional intensity**: Love is often accompanied by intense emotions such as joy, happiness, excitement, or euphoria.
# 2. **Attachment**: A strong desire to be with the loved one, physically and emotionally, and a sense of belongingness.
# 3. **Caring and concern**: A genuine interest in the well-being, growth, and happiness of the loved one.
# 4. **Commitment**: A willingness to make sacrifices, compromises, and long-term investments for
#
# --- 시도 3 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection with another person, place, or thing that evokes feelings of warmth, tenderness, care, and devotion. It involves a deep sense of attachment, affection, and commitment, which can manifest in various forms, such as romantic love, familial love, platonic love, self-love, or even unconditional love for all beings.
#
# Some key characteristics of love include:
#
# 1. **Emotional intensity**: Love is often accompanied by strong emotions like joy, excitement, nervousness, or euphoria.
# 2. **Attachment and bonding**: Love creates a sense of connection and belonging with the loved one, which can lead to feelings of security, comfort, and trust.
# 3. **Vulnerability**: Loving someone means being open and vulnerable, willing to take
#
# --- 시도 4 ---
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, compassion, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intensity**: Love is often accompanied by intense emotions such as joy, happiness, excitement, and euphoria.
# 2. **Attachment**: A strong desire to be with the loved one, physically or emotionally, and a sense of belongingness.
# 3. **Empathy**: The ability to understand, share, and validate the feelings and experiences of the loved one.
# 4. **Compassion**: A deep concern for the well-being, happiness, and flourishing
#
# --- 시도 5 ---
# The age-old question: what is love?
#
# Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. While it's difficult to define with absolute precision, here are some common characteristics and aspects of love:
#
# 1. **Emotional connection**: Love often involves an emotional bond between two individuals or entities (e.g., romantic partners, family members, friends). This connection can be characterized by feelings such as warmth, tenderness, affection, and intimacy.
# 2. **Positive emotions**: Love is typically associated with positive emotions like joy, happiness, contentment, and fulfillment. It's often accompanied by a sense of well-being and satisfaction.
# 3. **Commitment**: Love often involves a commitment to care for another person or entity over time, through thick and thin. This can manifest as loyalty, dedication, and sacrifice.
# 4. **Vulnerability**: Love requires vulnerability – being open, honest, and willing to take risks in the relationship.

# %% [markdown]
# **🤔 생각해보기**: temp=0.0과 temp=1.0의 결과가 어떻게 다른가요?
# 어떤 상황에서 temp를 높이거나 낮추는 것이 좋을까요?
#
# - 고객 응대 챗봇이라면? → temp를 **낮게** (일관된 답변)
# - 창작 글쓰기 도우미라면? → temp를 **높게** (다양한 표현)
#
# ### 2-2. Top P 실험
#
# Top P는 확률이 높은 토큰부터 누적하여, 합이 p가 될 때까지의 토큰에서만 선택합니다.
# top_p=1.0이면 모든 토큰을 고려, top_p=0.1이면 상위 확률 토큰만 고려합니다.

# %%
# top_p = 1.0 (모든 토큰 고려)
print("=== top_p=1.0 ===")
with model.chat_session():
    print(model.generate("Define love", max_tokens=200, top_p=1.0))
# Out:
# === top_p=1.0 ===
# Defining love is a daunting task, as it's a complex and multifaceted emotion that can be experienced in many different ways. Here are some possible definitions of love:
#
# 1. **Strong affection or attachment**: Love is a deep emotional connection with someone or something, characterized by feelings of tenderness, warmth, and devotion.
# 2. **Unconditional acceptance**: Love involves accepting and embracing the other person for who they are, without judgment or expectation of change.
# 3. **Vulnerability and risk-taking**: Loving someone means being willing to be vulnerable and take risks in order to build a deeper connection with them.
# 4. **Emotional investment**: Love is an emotional investment in another person's well-being, happiness, and success.
# 5. **Selfless giving**: Love often involves putting the needs of others before one's own, sacrificing for their benefit, and prioritizing their welfare.
#
# Some philosophers have offered more nuanced definitions:
#
# * Plato believed that love was a desire to possess or be possessed

# %%
# top_p = 0.1 (상위 확률 토큰만)
print("=== top_p=0.1 ===")
with model.chat_session():
    print(model.generate("Define love", max_tokens=200, top_p=0.1))
# Out:
# === top_p=0.1 ===
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment

# %% [markdown]
# ### 2-3. Top K 실험
#
# Top K는 확률이 높은 상위 K개의 토큰에서만 다음 단어를 선택합니다.
# K가 작을수록 선택지가 줄어들어 단조로운 답변이 나올 수 있습니다.

# %%
# top_k = 2 (상위 2개 토큰에서만 선택 — 매우 제한적)
print("=== top_k=2 ===")
with model.chat_session():
    print(model.generate("Define love", max_tokens=200, top_k=2))
# Out:
# === top_k=2 ===
# Defining love is a challenging but fascinating task! Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. Here's an attempt to provide a comprehensive definition:
#
# Love is a profound emotional connection characterized by strong feelings of affection, attachment, care, commitment, and devotion towards another person, place, or thing. It encompasses various forms, including romantic love, familial love, platonic love, self-love, and even unconditional love.
#
# Some key aspects of love include:
#
# 1. **Emotional intimacy**: A deep sense of connection and understanding with the loved one.
# 2. **Vulnerability**: Willingness to be open, honest, and vulnerable in front of the other person.
# 3. **Empathy**: The ability to understand and share the feelings, needs, and perspectives of the loved one.
# 4. **Acceptance**: Unconditional acceptance of the loved one's flaws, imperfections, and differences.
# 5. **Commitment

# %%
# top_k = 40 (기본값 수준 — 충분한 선택지)
print("=== top_k=40 ===")
with model.chat_session():
    print(model.generate("Define love", max_tokens=200, top_k=40))
# Out:
# === top_k=40 ===
# The age-old question: what is love?
#
# Love is a complex and multifaceted emotion that has been debated, explored, and experienced by humans for centuries. While it's difficult to define with absolute precision, here are some common aspects of love:
#
# 1. **Emotional connection**: Love often involves a strong emotional bond between two individuals, characterized by feelings of affection, tenderness, and warmth.
# 2. **Intimacy**: Physical intimacy is an essential aspect of romantic love, but it can also refer to the deep emotional closeness that develops over time with someone you care about deeply.
# 3. **Commitment**: Love often involves a willingness to commit to another person, making sacrifices for their well-being and happiness, and being willing to work through challenges together.
# 4. **Vulnerability**: Loving someone means being open and vulnerable, sharing your thoughts, feelings, and desires with them, and trusting that they will do the same in return.
# 5. **Unconditional acceptance**: Love can

# %% [markdown]
# **🤔 생각해보기**: top_k=2일 때와 top_k=40일 때 결과가 어떻게 다른가요?
# top_k가 너무 작으면 어떤 문제가 생길 수 있을까요?

# %% [markdown]
# ---
# ## 3. GPU(CUDA) 가속 사용
#
# GPU가 있는 환경(Colab GPU 런타임, 또는 NVIDIA GPU가 탑재된 로컬 PC)에서는 CUDA 가속을 사용할 수 있습니다.
#
# ⚠️ **Colab 사용자**: 아래 셀을 실행하기 전에 **런타임 > 세션 다시 시작**을 해주세요!
# ⚠️ **로컬 사용자**: 커널을 재시작한 후 아래부터 실행해주세요.

# %%
# !pip install "gpt4all[cuda]"
# Apple Silicon(M1/M2/M3)을 사용하는 경우:
# !pip install "gpt4all[metal]"
# Out:
# Collecting gpt4all[cuda]
#   Downloading gpt4all-2.8.2-py3-none-manylinux1_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gpt4all[cuda]) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gpt4all[cuda]) (4.67.3)
# Collecting nvidia-cuda-runtime-cu11 (from gpt4all[cuda])
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cublas-cu11 (from gpt4all[cuda])
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all[cuda]) (2026.2.25)
# Downloading gpt4all-2.8.2-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 9.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 66.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cublas-cu11, gpt4all
# Successfully installed gpt4all-2.8.2 nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-runtime-cu11-11.8.89

# %%
from gpt4all import GPT4All
import time

model = GPT4All("Meta-Llama-3-8B-Instruct.Q4_0.gguf", device="cuda")
# Apple Silicon: device="metal"
# Out:
# Downloading: 100%|██████████| 4.66G/4.66G [01:26<00:00, 54.0MiB/s]
# Verifying: 100%|██████████| 4.66G/4.66G [00:08<00:00, 545MiB/s]

# %% [markdown]
# CPU로 돌렸을 때와 동일한 질문을 GPU로 돌려봅시다.
# 시간을 측정해서 속도 차이를 확인합니다.

# %%
start = time.time()
with model.chat_session():
    result = model.generate("How can I run LLMs efficiently on my laptop?", max_tokens=1024)
elapsed = time.time() - start

print(result)
print(f"\n⏱️ 소요 시간: {elapsed:.1f}초")
# Out:
# Large Language Models (LLMs) are powerful AI models that require significant computational resources to train and use. Running them efficiently on a laptop requires careful planning, optimization, and selection of the right tools and techniques. Here's a comprehensive guide to help you get started:
#
# 1. **Choose the right LLM architecture**: Not all LLMs are created equal. Opt for smaller models like BERT-base or DistilBERT, which require less computational resources compared to larger models like RoBERTa-Large.
# 2. **Select an efficient framework**: Popular frameworks like Hugging Face's Transformers and PyTorch provide optimized implementations of LLMs. Choose the one that best fits your needs and expertise.
# 3. **Use a GPU (if possible)**: If you have a laptop with a dedicated graphics card, use it to accelerate computations. This can significantly reduce training times. You can also consider using cloud-based GPUs or renting one from services like Google Colab or AWS SageMaker.
# 4. **Optimize your code**: Ensure that your Python code is optimized for performance by:
# 	* Using NumPy and SciPy libraries for efficient numerical operations.
# 	* Implementing batch processing to reduce the number of iterations.
# 	* Minimizing memory allocation and deallocation.
# 5. **Use a suitable optimizer**: Select an optimizer that's well-suited for LLMs, such as AdamW or Adagrad. These optimizers are designed to handle large models and can help improve training efficiency.
# 6. **Adjust hyperparameters**: Experiment with different hyperparameter settings to find the optimal combination for your specific use case. This may involve adjusting learning rates, batch sizes, and number of epochs.
# 7. **Use a smaller dataset (if possible)**: If you're working on a specific task or domain, consider using a smaller dataset that's more representative of your target problem. This can reduce training times and computational requirements.
# 8. **Take advantage of parallelization**: Leverage multi-core processors by using libraries like joblib or dask to parallelize computations. This can significantly speed up processing times on laptops with multiple CPU cores.
# 9. **Use cloud-based services (if needed)**: If you don't have a suitable laptop configuration, consider using cloud-based services like Google Colab, AWS SageMaker, or Azure Machine Learning. These platforms provide scalable infrastructure and pre-configured environments for LLMs.
# 10. **Monitor system resources**: Keep an eye on your laptop's CPU usage, memory consumption, and disk space to ensure that you're not overwhelming the machine with too many computations.
#
# By following these guidelines, you can efficiently run LLMs on your laptop:
#
# * For smaller models like BERT-base or DistilBERT: 1-2 hours of training time using a GPU (if available) or around 4-6 hours without one.
# * For larger models like RoBERTa-Large: 8-12 hours of training time with a GPU, and up to several days without one.
#
# Remember that these estimates are approximate and may vary depending on your specific use case, laptop configuration, and the complexity of your task.
#
# ⏱️ 소요 시간: 27.9초

# %% [markdown]
# CPU에서는 약 1~2분 걸렸던 것이, GPU에서는 약 20\~30초로 단축됩니다.
# 슬라이드에서 배운 GPU/CUDA의 효과를 직접 체감할 수 있습니다!
#
# ---
# ## 4. 자유 실습
#
# 아래 셀을 활용해서 다양한 실험을 해보세요!
#
# **실습 과제:**
# 1. 질문을 바꿔서 모델의 응답을 확인해보세요 (한국어도 시도해보세요)
# 2. `temp`, `top_p`, `top_k` 를 동시에 조합해서 바꿔보세요
# 3. `max_tokens` 를 줄이거나 늘려보며 출력 길이를 조절해보세요
# 4. 모델의 응답에서 어떤 점이 부족한지 생각해보세요

# %%
# 하이퍼파라미터 비교 실험
# 같은 질문으로 서로 다른 설정의 결과를 나란히 비교해봅시다

question = "What is the meaning of life?"

configs = [
    {"temp": 0.0, "top_k": 40,  "label": "보수적 (temp=0.0)"},
    {"temp": 0.7, "top_k": 40,  "label": "균형 (temp=0.7)"},
    {"temp": 1.0, "top_k": 40,  "label": "창의적 (temp=1.0)"},
    {"temp": 0.7, "top_k": 2,   "label": "제한적 (top_k=2)"},
]

for cfg in configs:
    print(f"\n{'='*60}")
    print(f"설정: {cfg['label']}")
    print(f"{'='*60}")
    with model.chat_session():
        result = model.generate(
            question,
            max_tokens=1000,
            temp=cfg["temp"],
            top_k=cfg["top_k"]
        )
        print(result)
# Out:
# ============================================================
# 설정: 보수적 (temp=0.0)
# ============================================================
# The question that has puzzled philosophers, theologians, and scientists for centuries!
#
# There is no one definitive answer to this question, as it is a deeply personal and subjective inquiry. However, here are some possible perspectives:
#
# 1. **Existentialist perspective**: The meaning of life may be found in the individual's experience and choices. According to existentialists like Jean-Paul Sartre and Martin Heidegger, human beings have complete freedom to create their own purpose and significance.
# 2. **Religious or spiritual perspective**: Many religious traditions believe that the meaning of life is to fulfill a higher purpose or connect with a divine being. For example, in Christianity, Jesus Christ's teachings emphasize loving one another and serving others as the key to finding eternal life.
# 3. **Humanist perspective**: From a humanistic viewpoint, the meaning of life can be found in living a fulfilling, meaningful, and happy life. This might involve pursuing personal goals, building strong relationships, or contributing to society through work or volunteering.
# 4. **Scientific perspective**: Some scientists argue that the meaning of life is simply to survive and reproduce, as these are fundamental drives for many species. Others propose that our existence has no inherent meaning, but we can create our own purpose by pursuing knowledge, understanding, and personal growth.
# 5. **Philosophical perspectives**:
# 	* **Eudaimonic perspective**: Aristotle believed that the ultimate goal of human life is to achieve happiness (eudaimonia) through living a virtuous and fulfilling life.
# 	* **Absurdism**: The absurdity of existence can be seen as an inherent part of human experience, leading some philosophers like Albert Camus to argue that we must create our own meaning in the face of uncertainty.
#
# Ultimately, the meaning of life is a highly subjective and personal question. It may depend on individual values, beliefs, experiences, and goals. Some people might find meaning through:
#
# * Pursuing their passions or interests
# * Building strong relationships with others
# * Contributing to society or making a positive impact
# * Seeking spiritual growth or connection with something greater than themselves
# * Achieving personal fulfillment or happiness
#
# Remember that there is no one "right" answer, and the search for meaning can be an ongoing process.
#
# ============================================================
# 설정: 균형 (temp=0.7)
# ============================================================
# The question that has puzzled philosophers, theologians, and scientists for centuries!
#
# There is no one definitive answer to this question, as it is a deeply personal and subjective inquiry. However, here are some possible perspectives:
#
# 1. **Existentialist perspective**: From an existentialist viewpoint, the meaning of life is created by individuals themselves through their choices, actions, and experiences. It's up to each person to decide what gives their life significance.
# 2. **Religious or spiritual perspective**: Many religious traditions believe that the meaning of life is connected to a higher power, purpose, or divine plan. For example, some Christians see Jesus Christ as the source of eternal life and salvation, while others may find meaning in following the teachings of Buddha or other spiritual leaders.
# 3. **Humanist perspective**: From a humanistic standpoint, the meaning of life can be found in living a fulfilling, meaningful, and purposeful existence. This might involve pursuing one's passions, contributing to society, fostering relationships, and cultivating personal growth.
# 4. **Scientific perspective**: Some scientists argue that the meaning of life is simply to survive and reproduce, as these are fundamental drives for many species. Others propose that humans have evolved to seek out complex social structures, cultural development, and intellectual pursuits.
# 5. **Philosophical perspectives**:
# 	* **Eudaimonic approach**: Aristotle believed that living a virtuous life (eudaimonia) was the key to finding meaning. This involves cultivating character traits like wisdom, courage, and justice.
# 	* **Hedonic approach**: Epicurus argued that happiness (hedone) is the ultimate goal of human existence. He advocated for living modestly, avoiding pain and fear, and seeking simple pleasures in life.
# 6. **Pragmatic perspective**: Some people find meaning by focusing on what they can control and achieving their goals. This might involve setting realistic targets, building meaningful relationships, or pursuing personal interests.
#
# Ultimately, the meaning of life is a highly subjective and individualized concept that may vary greatly from person to person. It's up to each individual to reflect on their values, beliefs, and experiences to discover what gives their life significance.
#
# What do you think? Do any of these perspectives resonate with you, or do you have your own ideas about the meaning of life?
#
# ============================================================
# 설정: 창의적 (temp=1.0)
# ============================================================
# The question that has puzzled philosophers, theologians, and scientists for centuries!
#
# There is no one definitive answer to this question, as it is a deeply personal and subjective inquiry. However, here are some possible perspectives:
#
# 1. **Existentialist perspective**: The meaning of life may be found in the individual's experience and choices. According to existentialists like Jean-Paul Sartre and Martin Heidegger, human beings have complete freedom to create their own purpose and significance.
# 2. **Religious or spiritual perspective**: Many religious traditions believe that the meaning of life is to fulfill a higher purpose or connect with a divine being. For example, in Christianity, Jesus Christ's teachings emphasize loving one another and serving others as the key to finding fulfillment.
# 3. **Humanist perspective**: Humanists like Aristotle and Immanuel Kant argue that human beings have inherent value and dignity, which gives life meaning. The pursuit of knowledge, self-actualization, and contributing to society can be seen as ways to find purpose.
# 4. **Scientific perspective**: Some scientists suggest that the meaning of life may be found in the natural world or our place within it. For example, evolutionary biologist E.O. Wilson proposes that humans have an innate desire for transcendence, which drives us to seek answers about the universe and our existence.
# 5. **Philosophical perspectives**:
# 	* **Hedonism**: The pursuit of pleasure and happiness can be seen as a way to find meaning in life (e.g., Epicureanism).
# 	* **Virtue ethics**: Living a virtuous life, characterized by moral excellence and character development, can bring fulfillment.
# 	* **Existential nihilism**: Some philosophers argue that the search for meaning is ultimately futile, and we must accept our mortality and the uncertainty of existence (e.g., Friedrich Nietzsche).
#
# Ultimately, the meaning of life may be unique to each individual. It's a question that has been debated throughout history, and there is no one "right" answer.
#
# What do you think? Do any of these perspectives resonate with you, or do you have your own ideas about what gives life its meaning?
#
# ============================================================
# 설정: 제한적 (top_k=2)
# ============================================================
# The question that has puzzled philosophers, theologians, and scientists for centuries!
#
# There is no one definitive answer to this question, as it is a deeply personal and subjective inquiry. However, here are some possible perspectives:
#
# 1. **Existentialist perspective**: The meaning of life may be found in the individual's experience and choices. According to existentialists like Jean-Paul Sartre and Martin Heidegger, human beings have complete freedom to create their own purpose and significance.
# 2. **Religious or spiritual perspective**: Many religious traditions believe that the meaning of life is to fulfill a higher purpose or connect with a divine being. For example, in Christianity, Jesus Christ's teachings emphasize loving one another and serving others as the key to finding eternal life.
# 3. **Humanist perspective**: From a humanistic viewpoint, the meaning of life can be found in living a fulfilling, meaningful, and happy life. This might involve pursuing personal goals, building strong relationships, or contributing to society through work or volunteering.
# 4. **Scientific perspective**: Some scientists argue that the meaning of life is simply to survive and reproduce, as these are fundamental drives for many species. Others propose that our existence has no inherent meaning, but we can create our own purpose by pursuing knowledge, understanding, and personal growth.
# 5. **Philosophical perspectives**:
# 	* **Eudaimonic perspective**: Aristotle believed that the ultimate goal of human life is to achieve happiness (eudaimonia) through living a virtuous and fulfilling life.
# 	* **Absurdism**: The absurdity of existence can be seen as an inherent part of human experience, leading some philosophers like Albert Camus to argue that we must create our own meaning in the face of uncertainty.
#
# Ultimately, the meaning of life is a highly subjective and personal question. It may depend on individual values, beliefs, experiences, and goals. Some people might find meaning through:
#
# * Pursuing their passions or interests
# * Building strong relationships with others
# * Contributing to society or making a positive impact
# * Seeking spiritual growth or connection with something greater than themselves
# * Achieving personal fulfillment or happiness
#
# Remember that there is no one "right" answer, and the search for meaning can be an ongoing process.

# %% [markdown]
# ---
# ## 정리
#
# 오늘 실습에서 확인한 것:
#
# - `GPT4All` 라이브러리로 Python에서 로컬 LLM을 쉽게 사용할 수 있다
# - `temp` → 높을수록 다양한 응답, 낮을수록 일관된 응답
# - `top_p`, `top_k` → 낮을수록 보수적인 단어 선택
# - `device="cuda"` → GPU 가속으로 5배 이상 속도 향상
#
# **다음 시간에는:**
# GPT4ALL에서 사용 가능한 다양한 모델(LLaMA, Mistral, Phi)의 특성을 비교하고,
# 모델마다 다른 **프롬프트 형식**을 이해합니다.
